# %%
import pandas as pd
PATH = '../../datos/datos_por_estacion/SUROESTE2.xlsx'
data_2025 = pd.read_excel(PATH, sheet_name='2025')

# %%
data_2025 = data_2025[['date','PM10', 'NO2', 'CO', 'SO2','O3', 'PM2.5']]

# %%
data_2025.head()
# Out:
#                  date  PM10   NO2    CO  SO2    O3  PM2.5
# 0 2025-01-01 00:00:00   NaN   7.3  2.79  4.5  37.0   26.0
# 1 2025-01-01 01:00:00   NaN  16.3  0.40  5.0  30.0   41.0
# 2 2025-01-01 02:00:00   NaN  10.0  0.24  4.3  37.0   35.0
# 3 2025-01-01 03:00:00   NaN   8.8  0.22  3.4  34.0   22.0
# 4 2025-01-01 04:00:00   NaN   7.7  0.22  3.4  34.0   16.0

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
len(data_2025)
# Out:
# 4343

# %%
faltantes(data_2025)
# Out:
# Faltantes totales en el DataFrame: 1445
# (PM2.5    912
#  PM10     275
#  CO       156
#  O3        76
#  NO2       13
#  SO2       13
#  date       0
#  dtype: int64,
#  1445)

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
plotserie(data_2025, 'SO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2025'}>,
#          <Axes: title={'center': 'Feb 2025'}>,
#          <Axes: title={'center': 'Mar 2025'}>,
#          <Axes: title={'center': 'Apr 2025'}>],
#         [<Axes: title={'center': 'May 2025'}>,
#          <Axes: title={'center': 'Jun 2025'}>,
#          <Axes: title={'center': 'Jul 2025'}>,
#          <Axes: title={'center': 'Aug 2025'}>],
#         [<Axes: title={'center': 'Sep 2025'}>,
#          <Axes: title={'center': 'Oct 2025'}>,
#          <Axes: title={'center': 'Nov 2025'}>,
#          <Axes: title={'center': 'Dec 2025'}>]], dtype=object))

# %%
plotserie(data_2025, 'NO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2025'}>,
#          <Axes: title={'center': 'Feb 2025'}>,
#          <Axes: title={'center': 'Mar 2025'}>,
#          <Axes: title={'center': 'Apr 2025'}>],
#         [<Axes: title={'center': 'May 2025'}>,
#          <Axes: title={'center': 'Jun 2025'}>,
#          <Axes: title={'center': 'Jul 2025'}>,
#          <Axes: title={'center': 'Aug 2025'}>],
#         [<Axes: title={'center': 'Sep 2025'}>,
#          <Axes: title={'center': 'Oct 2025'}>,
#          <Axes: title={'center': 'Nov 2025'}>,
#          <Axes: title={'center': 'Dec 2025'}>]], dtype=object))

# %%
plotserie(data_2025, 'O3')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2025'}>,
#          <Axes: title={'center': 'Feb 2025'}>,
#          <Axes: title={'center': 'Mar 2025'}>,
#          <Axes: title={'center': 'Apr 2025'}>],
#         [<Axes: title={'center': 'May 2025'}>,
#          <Axes: title={'center': 'Jun 2025'}>,
#          <Axes: title={'center': 'Jul 2025'}>,
#          <Axes: title={'center': 'Aug 2025'}>],
#         [<Axes: title={'center': 'Sep 2025'}>,
#          <Axes: title={'center': 'Oct 2025'}>,
#          <Axes: title={'center': 'Nov 2025'}>,
#          <Axes: title={'center': 'Dec 2025'}>]], dtype=object))

# %%
plotserie(data_2025, 'CO')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2025'}>,
#          <Axes: title={'center': 'Feb 2025'}>,
#          <Axes: title={'center': 'Mar 2025'}>,
#          <Axes: title={'center': 'Apr 2025'}>],
#         [<Axes: title={'center': 'May 2025'}>,
#          <Axes: title={'center': 'Jun 2025'}>,
#          <Axes: title={'center': 'Jul 2025'}>,
#          <Axes: title={'center': 'Aug 2025'}>],
#         [<Axes: title={'center': 'Sep 2025'}>,
#          <Axes: title={'center': 'Oct 2025'}>,
#          <Axes: title={'center': 'Nov 2025'}>,
#          <Axes: title={'center': 'Dec 2025'}>]], dtype=object))

# %%
plotserie(data_2025, 'PM2.5')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2025'}>,
#          <Axes: title={'center': 'Feb 2025'}>,
#          <Axes: title={'center': 'Mar 2025'}>,
#          <Axes: title={'center': 'Apr 2025'}>],
#         [<Axes: title={'center': 'May 2025'}>,
#          <Axes: title={'center': 'Jun 2025'}>,
#          <Axes: title={'center': 'Jul 2025'}>,
#          <Axes: title={'center': 'Aug 2025'}>],
#         [<Axes: title={'center': 'Sep 2025'}>,
#          <Axes: title={'center': 'Oct 2025'}>,
#          <Axes: title={'center': 'Nov 2025'}>,
#          <Axes: title={'center': 'Dec 2025'}>]], dtype=object))

# %%
plotserie(data_2025, 'PM10')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2025'}>,
#          <Axes: title={'center': 'Feb 2025'}>,
#          <Axes: title={'center': 'Mar 2025'}>,
#          <Axes: title={'center': 'Apr 2025'}>],
#         [<Axes: title={'center': 'May 2025'}>,
#          <Axes: title={'center': 'Jun 2025'}>,
#          <Axes: title={'center': 'Jul 2025'}>,
#          <Axes: title={'center': 'Aug 2025'}>],
#         [<Axes: title={'center': 'Sep 2025'}>,
#          <Axes: title={'center': 'Oct 2025'}>,
#          <Axes: title={'center': 'Nov 2025'}>,
#          <Axes: title={'center': 'Dec 2025'}>]], dtype=object))
