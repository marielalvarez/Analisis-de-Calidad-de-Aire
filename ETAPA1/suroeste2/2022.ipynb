# %%
import pandas as pd
PATH = '../../datos/datos_por_estacion/SUROESTE2.xlsx'
data_2022 = pd.read_excel(PATH, sheet_name='2022')

# %%
data_2022 = data_2022[['date','PM10', 'NO2', 'CO', 'SO2','O3', 'PM2.5']]

# %%
data_2022.head()
# Out:
#                  date   PM10   NO2    CO  SO2    O3  PM2.5
# 0 2022-01-01 00:00:00  106.0  21.6  1.62  4.8  33.0   53.0
# 1 2022-01-01 01:00:00   89.0  12.9  1.33  4.4  36.0   49.0
# 2 2022-01-01 02:00:00   77.0  14.9  1.29  4.1  34.0   39.0
# 3 2022-01-01 03:00:00   54.0  21.2  1.40  4.7  25.0   35.0
# 4 2022-01-01 04:00:00   68.0  19.8  1.39  4.3  22.0   35.0

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
len(data_2022)
# Out:
# 8760

# %%
faltantes(data_2022)
# Out:
# Faltantes totales en el DataFrame: 1489
# (PM2.5    393
#  PM10     280
#  SO2      257
#  O3       232
#  CO       169
#  NO2      158
#  date       0
#  dtype: int64,
#  1489)

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
plotserie(data_2022, 'SO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2022'}>,
#          <Axes: title={'center': 'Feb 2022'}>,
#          <Axes: title={'center': 'Mar 2022'}>,
#          <Axes: title={'center': 'Apr 2022'}>],
#         [<Axes: title={'center': 'May 2022'}>,
#          <Axes: title={'center': 'Jun 2022'}>,
#          <Axes: title={'center': 'Jul 2022'}>,
#          <Axes: title={'center': 'Aug 2022'}>],
#         [<Axes: title={'center': 'Sep 2022'}>,
#          <Axes: title={'center': 'Oct 2022'}>,
#          <Axes: title={'center': 'Nov 2022'}>,
#          <Axes: title={'center': 'Dec 2022'}>]], dtype=object))

# %%
plotserie(data_2022, 'NO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2022'}>,
#          <Axes: title={'center': 'Feb 2022'}>,
#          <Axes: title={'center': 'Mar 2022'}>,
#          <Axes: title={'center': 'Apr 2022'}>],
#         [<Axes: title={'center': 'May 2022'}>,
#          <Axes: title={'center': 'Jun 2022'}>,
#          <Axes: title={'center': 'Jul 2022'}>,
#          <Axes: title={'center': 'Aug 2022'}>],
#         [<Axes: title={'center': 'Sep 2022'}>,
#          <Axes: title={'center': 'Oct 2022'}>,
#          <Axes: title={'center': 'Nov 2022'}>,
#          <Axes: title={'center': 'Dec 2022'}>]], dtype=object))

# %%
plotserie(data_2022, 'O3')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2022'}>,
#          <Axes: title={'center': 'Feb 2022'}>,
#          <Axes: title={'center': 'Mar 2022'}>,
#          <Axes: title={'center': 'Apr 2022'}>],
#         [<Axes: title={'center': 'May 2022'}>,
#          <Axes: title={'center': 'Jun 2022'}>,
#          <Axes: title={'center': 'Jul 2022'}>,
#          <Axes: title={'center': 'Aug 2022'}>],
#         [<Axes: title={'center': 'Sep 2022'}>,
#          <Axes: title={'center': 'Oct 2022'}>,
#          <Axes: title={'center': 'Nov 2022'}>,
#          <Axes: title={'center': 'Dec 2022'}>]], dtype=object))

# %%
plotserie(data_2022, 'CO')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2022'}>,
#          <Axes: title={'center': 'Feb 2022'}>,
#          <Axes: title={'center': 'Mar 2022'}>,
#          <Axes: title={'center': 'Apr 2022'}>],
#         [<Axes: title={'center': 'May 2022'}>,
#          <Axes: title={'center': 'Jun 2022'}>,
#          <Axes: title={'center': 'Jul 2022'}>,
#          <Axes: title={'center': 'Aug 2022'}>],
#         [<Axes: title={'center': 'Sep 2022'}>,
#          <Axes: title={'center': 'Oct 2022'}>,
#          <Axes: title={'center': 'Nov 2022'}>,
#          <Axes: title={'center': 'Dec 2022'}>]], dtype=object))

# %%
plotserie(data_2022, 'PM2.5')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2022'}>,
#          <Axes: title={'center': 'Feb 2022'}>,
#          <Axes: title={'center': 'Mar 2022'}>,
#          <Axes: title={'center': 'Apr 2022'}>],
#         [<Axes: title={'center': 'May 2022'}>,
#          <Axes: title={'center': 'Jun 2022'}>,
#          <Axes: title={'center': 'Jul 2022'}>,
#          <Axes: title={'center': 'Aug 2022'}>],
#         [<Axes: title={'center': 'Sep 2022'}>,
#          <Axes: title={'center': 'Oct 2022'}>,
#          <Axes: title={'center': 'Nov 2022'}>,
#          <Axes: title={'center': 'Dec 2022'}>]], dtype=object))

# %%
plotserie(data_2022, 'PM10')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2022'}>,
#          <Axes: title={'center': 'Feb 2022'}>,
#          <Axes: title={'center': 'Mar 2022'}>,
#          <Axes: title={'center': 'Apr 2022'}>],
#         [<Axes: title={'center': 'May 2022'}>,
#          <Axes: title={'center': 'Jun 2022'}>,
#          <Axes: title={'center': 'Jul 2022'}>,
#          <Axes: title={'center': 'Aug 2022'}>],
#         [<Axes: title={'center': 'Sep 2022'}>,
#          <Axes: title={'center': 'Oct 2022'}>,
#          <Axes: title={'center': 'Nov 2022'}>,
#          <Axes: title={'center': 'Dec 2022'}>]], dtype=object))
