# %% [markdown]
# ### Este es el notebook que genera los datos de la Estación Suroeste 2 (2021-2025) desde los datos crudos

# %%
from pathlib import Path
NB_DIR = Path.cwd() 
print(NB_DIR)

DATA_CRUDOS = NB_DIR.parents[1] / "datos/datos_crudos"   

file_2021 = DATA_CRUDOS / "DATOS HISTÓRICOS 2020_2021_TODAS ESTACIONES.xlsx"
file_2223 = DATA_CRUDOS /"DATOS HISTÓRICOS 2022_2023_TODAS ESTACIONES.xlsx"
file_2324 = DATA_CRUDOS / "DATOS HISTÓRICOS 2023_2024_TODAS ESTACIONES_ITESM.xlsx"
file_2025 = DATA_CRUDOS / "BD 2025.xlsx"
# Out:
# /Users/marielalvarez/2025/5to_sem/multivariados/RETO/ETAPA1/suroeste2

# %%
from pathlib import Path
print(Path.cwd())                               
print((Path.cwd().parent / "unir_datos.py").exists())
# Out:
# /Users/marielalvarez/2025/5to_sem/multivariados/RETO/ETAPA1/suroeste2
# True

# %%
from pathlib import Path
import sys

sys.path.insert(0, str(Path.cwd().parent))

# %%
from unir_datos import *
import pandas as pd
STATION = "SUROESTE2"

df_2021_sheet = pd.read_excel(file_2021, sheet_name=STATION, header=0)
df_2022_sheet = pd.read_excel(file_2223, sheet_name=STATION, header=0)
raw_2023_2024 = pd.read_excel(file_2324, header=[0, 1, 2])
df_2025_sheet = pd.read_excel(file_2025 ,sheet_name="SO2", header=0)

df21, df22, df23, df24, df25 = station_to_5dfs(
    df_2021_sheet,    
    df_2022_sheet,      
    raw_2023_2024,      
    df_2025_sheet,      
    station=STATION
)
# Out:
# /Users/marielalvarez/2025/5to_sem/multivariados/RETO/ETAPA1/unir_datos.py:42: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(to_replace=r"^\s*(NULL|null|NaN|nan)\s*$", value=pd.NA, regex=True)

# %%
df21
# Out:
#                     date    CO   NO   NO2   NOX    O3   PM10  PM2.5    PRS  \
# 0    2021-01-01 00:00:00  3.62  2.1  15.1  17.0  18.0   79.0    NaN    NaN
# 1    2021-01-01 01:00:00  3.91  4.9  22.5  27.3   5.0   74.0    NaN  712.5
# 2    2021-01-01 02:00:00  3.57  2.1  11.9  13.9  15.0  106.0    NaN  712.5
# 3    2021-01-01 03:00:00  3.61  2.2  16.3  18.4  10.0   63.0    NaN  712.7
# 4    2021-01-01 04:00:00  3.61  3.6  21.5  25.1   4.0   63.0    NaN  712.8
# ...                  ...   ...  ...   ...   ...   ...    ...    ...    ...
# 8754 2021-12-31 19:00:00  1.23  2.6  20.0  22.6  67.0   43.0   20.0  710.9
# 8755 2021-12-31 20:00:00  1.37  2.6  21.0  23.7  63.0   63.0   25.0  711.1
# 8756 2021-12-31 21:00:00  1.50  2.7  23.9  26.6  49.0   67.0   39.0  711.3
# 8757 2021-12-31 22:00:00  1.85  2.7  29.5  32.3  35.0   79.0   49.0  711.4
# 8758 2021-12-31 23:00:00  1.91  2.6  35.0  37.7  26.0  101.0   59.0  711.4
#
#       RAINF    RH  SO2   SR   TOUT  WSR    WDR
# 0       NaN  43.0  3.2  0.0  11.70  NaN    NaN
# 1       0.0  62.0  3.2  0.0   9.07  0.6   98.0
# 2       0.0  67.0  3.2  0.0   7.78  0.6  107.0
# 3       0.0  69.0  3.1  0.0   6.98  0.6  106.0
# 4       0.0  72.0  3.2  0.0   6.22  NaN  100.0
# ...     ...   ...  ...  ...    ...  ...    ...
# 8754    0.0  35.0  4.2  0.0  26.27  9.8   82.0
# 8755    0.0  42.0  4.2  0.0  24.85  7.2  137.0
# 8756    0.0  47.0  4.1  0.0  23.22  6.6  200.0
# 8757    0.0  45.0  4.3  0.0  22.29  5.9  228.0
# 8758    0.0  43.0  4.6  0.0  21.31  7.1  233.0
#
# [8759 rows x 16 columns]

# %% [markdown]
# ## guarda los datos listos para analisis en data/

# %%
with pd.ExcelWriter("../../datos/datos_por_estacion/SUROESTE2.xlsx", engine="openpyxl") as writer:
    df21.to_excel(writer, sheet_name="2021", index=False)
    df22.to_excel(writer, sheet_name="2022", index=False)
    df23.to_excel(writer, sheet_name="2023", index=False)
    df24.to_excel(writer, sheet_name="2024", index=False)
    df25.to_excel(writer, sheet_name="2025", index=False)
