# %%
import pandas as pd
PATH = '../../datos/datos_por_estacion/SUROESTE2.xlsx'
data_2024 = pd.read_excel(PATH, sheet_name='2024')

# %%
data_2024 = data_2024[['date','PM10', 'NO2', 'CO', 'SO2','O3', 'PM2.5']]

# %%
data_2024.head()
# Out:
#                  date   PM10   NO2    CO  SO2    O3  PM2.5
# 0 2024-01-01 00:00:00  114.0  25.8  1.94  3.2  13.0   80.0
# 1 2024-01-01 01:00:00  114.0  22.0  1.94  4.0  23.0   80.0
# 2 2024-01-01 02:00:00  102.0  24.0  1.73  3.8  20.0   66.0
# 3 2024-01-01 03:00:00   82.0  27.1  1.87  3.8  15.0   55.0
# 4 2024-01-01 04:00:00   76.0  23.3  1.54  3.5  18.0   41.0

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
len(data_2024)
# Out:
# 5112

# %%
faltantes(data_2024)
# Out:
# Faltantes totales en el DataFrame: 960
# (PM2.5    480
#  PM10     315
#  O3        77
#  SO2       38
#  NO2       26
#  CO        24
#  date       0
#  dtype: int64,
#  960)

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
plotserie(data_2024, 'SO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2024'}>,
#          <Axes: title={'center': 'Feb 2024'}>,
#          <Axes: title={'center': 'Mar 2024'}>,
#          <Axes: title={'center': 'Apr 2024'}>],
#         [<Axes: title={'center': 'May 2024'}>,
#          <Axes: title={'center': 'Jun 2024'}>,
#          <Axes: title={'center': 'Jul 2024'}>,
#          <Axes: title={'center': 'Aug 2024'}>],
#         [<Axes: title={'center': 'Sep 2024'}>,
#          <Axes: title={'center': 'Oct 2024'}>,
#          <Axes: title={'center': 'Nov 2024'}>,
#          <Axes: title={'center': 'Dec 2024'}>]], dtype=object))

# %%
plotserie(data_2024, 'NO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2024'}>,
#          <Axes: title={'center': 'Feb 2024'}>,
#          <Axes: title={'center': 'Mar 2024'}>,
#          <Axes: title={'center': 'Apr 2024'}>],
#         [<Axes: title={'center': 'May 2024'}>,
#          <Axes: title={'center': 'Jun 2024'}>,
#          <Axes: title={'center': 'Jul 2024'}>,
#          <Axes: title={'center': 'Aug 2024'}>],
#         [<Axes: title={'center': 'Sep 2024'}>,
#          <Axes: title={'center': 'Oct 2024'}>,
#          <Axes: title={'center': 'Nov 2024'}>,
#          <Axes: title={'center': 'Dec 2024'}>]], dtype=object))

# %%
plotserie(data_2024, 'O3')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2024'}>,
#          <Axes: title={'center': 'Feb 2024'}>,
#          <Axes: title={'center': 'Mar 2024'}>,
#          <Axes: title={'center': 'Apr 2024'}>],
#         [<Axes: title={'center': 'May 2024'}>,
#          <Axes: title={'center': 'Jun 2024'}>,
#          <Axes: title={'center': 'Jul 2024'}>,
#          <Axes: title={'center': 'Aug 2024'}>],
#         [<Axes: title={'center': 'Sep 2024'}>,
#          <Axes: title={'center': 'Oct 2024'}>,
#          <Axes: title={'center': 'Nov 2024'}>,
#          <Axes: title={'center': 'Dec 2024'}>]], dtype=object))

# %%
plotserie(data_2024, 'CO')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2024'}>,
#          <Axes: title={'center': 'Feb 2024'}>,
#          <Axes: title={'center': 'Mar 2024'}>,
#          <Axes: title={'center': 'Apr 2024'}>],
#         [<Axes: title={'center': 'May 2024'}>,
#          <Axes: title={'center': 'Jun 2024'}>,
#          <Axes: title={'center': 'Jul 2024'}>,
#          <Axes: title={'center': 'Aug 2024'}>],
#         [<Axes: title={'center': 'Sep 2024'}>,
#          <Axes: title={'center': 'Oct 2024'}>,
#          <Axes: title={'center': 'Nov 2024'}>,
#          <Axes: title={'center': 'Dec 2024'}>]], dtype=object))

# %%
plotserie(data_2024, 'PM2.5')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2024'}>,
#          <Axes: title={'center': 'Feb 2024'}>,
#          <Axes: title={'center': 'Mar 2024'}>,
#          <Axes: title={'center': 'Apr 2024'}>],
#         [<Axes: title={'center': 'May 2024'}>,
#          <Axes: title={'center': 'Jun 2024'}>,
#          <Axes: title={'center': 'Jul 2024'}>,
#          <Axes: title={'center': 'Aug 2024'}>],
#         [<Axes: title={'center': 'Sep 2024'}>,
#          <Axes: title={'center': 'Oct 2024'}>,
#          <Axes: title={'center': 'Nov 2024'}>,
#          <Axes: title={'center': 'Dec 2024'}>]], dtype=object))

# %%
plotserie(data_2024, 'PM10')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2024'}>,
#          <Axes: title={'center': 'Feb 2024'}>,
#          <Axes: title={'center': 'Mar 2024'}>,
#          <Axes: title={'center': 'Apr 2024'}>],
#         [<Axes: title={'center': 'May 2024'}>,
#          <Axes: title={'center': 'Jun 2024'}>,
#          <Axes: title={'center': 'Jul 2024'}>,
#          <Axes: title={'center': 'Aug 2024'}>],
#         [<Axes: title={'center': 'Sep 2024'}>,
#          <Axes: title={'center': 'Oct 2024'}>,
#          <Axes: title={'center': 'Nov 2024'}>,
#          <Axes: title={'center': 'Dec 2024'}>]], dtype=object))
