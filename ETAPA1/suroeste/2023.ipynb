# %%
import pandas as pd
PATH = '../../datos/datos_por_estacion/SUROESTE.xlsx'
data_2023 = pd.read_excel(PATH, sheet_name='2023')

# %%
data_2023 = data_2023[['date','PM10', 'NO2', 'CO', 'SO2','O3', 'PM2.5']]

# %%
data_2023.head()
# Out:
#                  date   PM10   NO2    CO  SO2   O3  PM2.5
# 0 2023-01-01 00:00:00  221.0  40.6  3.67  4.4  8.0    NaN
# 1 2023-01-01 01:00:00  267.0  38.0  3.90  4.9  8.0    NaN
# 2 2023-01-01 02:00:00  320.0  35.7  4.28  5.5  8.0    NaN
# 3 2023-01-01 03:00:00  361.0  34.6  3.15  5.2  6.0  129.0
# 4 2023-01-01 04:00:00  166.0  31.8  2.32  5.1  6.0   74.0

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
len(data_2023)
# Out:
# 8758

# %%
faltantes(data_2023)
# Out:
# Faltantes totales en el DataFrame: 1491
# (PM2.5    577
#  O3       373
#  NO2      270
#  SO2      138
#  PM10      92
#  CO        41
#  date       0
#  dtype: int64,
#  1491)

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
plotserie(data_2023, 'SO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2023'}>,
#          <Axes: title={'center': 'Feb 2023'}>,
#          <Axes: title={'center': 'Mar 2023'}>,
#          <Axes: title={'center': 'Apr 2023'}>],
#         [<Axes: title={'center': 'May 2023'}>,
#          <Axes: title={'center': 'Jun 2023'}>,
#          <Axes: title={'center': 'Jul 2023'}>,
#          <Axes: title={'center': 'Aug 2023'}>],
#         [<Axes: title={'center': 'Sep 2023'}>,
#          <Axes: title={'center': 'Oct 2023'}>,
#          <Axes: title={'center': 'Nov 2023'}>,
#          <Axes: title={'center': 'Dec 2023'}>]], dtype=object))

# %%
plotserie(data_2023, 'NO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2023'}>,
#          <Axes: title={'center': 'Feb 2023'}>,
#          <Axes: title={'center': 'Mar 2023'}>,
#          <Axes: title={'center': 'Apr 2023'}>],
#         [<Axes: title={'center': 'May 2023'}>,
#          <Axes: title={'center': 'Jun 2023'}>,
#          <Axes: title={'center': 'Jul 2023'}>,
#          <Axes: title={'center': 'Aug 2023'}>],
#         [<Axes: title={'center': 'Sep 2023'}>,
#          <Axes: title={'center': 'Oct 2023'}>,
#          <Axes: title={'center': 'Nov 2023'}>,
#          <Axes: title={'center': 'Dec 2023'}>]], dtype=object))

# %%
plotserie(data_2023, 'O3')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2023'}>,
#          <Axes: title={'center': 'Feb 2023'}>,
#          <Axes: title={'center': 'Mar 2023'}>,
#          <Axes: title={'center': 'Apr 2023'}>],
#         [<Axes: title={'center': 'May 2023'}>,
#          <Axes: title={'center': 'Jun 2023'}>,
#          <Axes: title={'center': 'Jul 2023'}>,
#          <Axes: title={'center': 'Aug 2023'}>],
#         [<Axes: title={'center': 'Sep 2023'}>,
#          <Axes: title={'center': 'Oct 2023'}>,
#          <Axes: title={'center': 'Nov 2023'}>,
#          <Axes: title={'center': 'Dec 2023'}>]], dtype=object))

# %%
plotserie(data_2023, 'CO')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2023'}>,
#          <Axes: title={'center': 'Feb 2023'}>,
#          <Axes: title={'center': 'Mar 2023'}>,
#          <Axes: title={'center': 'Apr 2023'}>],
#         [<Axes: title={'center': 'May 2023'}>,
#          <Axes: title={'center': 'Jun 2023'}>,
#          <Axes: title={'center': 'Jul 2023'}>,
#          <Axes: title={'center': 'Aug 2023'}>],
#         [<Axes: title={'center': 'Sep 2023'}>,
#          <Axes: title={'center': 'Oct 2023'}>,
#          <Axes: title={'center': 'Nov 2023'}>,
#          <Axes: title={'center': 'Dec 2023'}>]], dtype=object))

# %%
plotserie(data_2023, 'PM2.5')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2023'}>,
#          <Axes: title={'center': 'Feb 2023'}>,
#          <Axes: title={'center': 'Mar 2023'}>,
#          <Axes: title={'center': 'Apr 2023'}>],
#         [<Axes: title={'center': 'May 2023'}>,
#          <Axes: title={'center': 'Jun 2023'}>,
#          <Axes: title={'center': 'Jul 2023'}>,
#          <Axes: title={'center': 'Aug 2023'}>],
#         [<Axes: title={'center': 'Sep 2023'}>,
#          <Axes: title={'center': 'Oct 2023'}>,
#          <Axes: title={'center': 'Nov 2023'}>,
#          <Axes: title={'center': 'Dec 2023'}>]], dtype=object))

# %%
plotserie(data_2023, 'PM10')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2023'}>,
#          <Axes: title={'center': 'Feb 2023'}>,
#          <Axes: title={'center': 'Mar 2023'}>,
#          <Axes: title={'center': 'Apr 2023'}>],
#         [<Axes: title={'center': 'May 2023'}>,
#          <Axes: title={'center': 'Jun 2023'}>,
#          <Axes: title={'center': 'Jul 2023'}>,
#          <Axes: title={'center': 'Aug 2023'}>],
#         [<Axes: title={'center': 'Sep 2023'}>,
#          <Axes: title={'center': 'Oct 2023'}>,
#          <Axes: title={'center': 'Nov 2023'}>,
#          <Axes: title={'center': 'Dec 2023'}>]], dtype=object))
