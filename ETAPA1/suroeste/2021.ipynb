# %%
import pandas as pd
PATH = '../../datos/datos_por_estacion/SUROESTE.xlsx'
data_2021 = pd.read_excel(PATH, sheet_name='2021')

# %%
data_2021 = data_2021[['date','PM10', 'NO2', 'CO', 'SO2','O3', 'PM2.5']]

# %%
data_2021.head()
# Out:
#                  date   PM10  NO2    CO  SO2    O3  PM2.5
# 0 2021-01-01 00:00:00   62.0  0.5  1.71  5.3  12.0  57.59
# 1 2021-01-01 01:00:00   79.0  0.5  2.12  6.0   8.0    NaN
# 2 2021-01-01 02:00:00  140.0  0.5  1.51  5.3   7.0  55.45
# 3 2021-01-01 03:00:00   79.0  0.5  1.46  5.1  10.0  50.38
# 4 2021-01-01 04:00:00   75.0  0.5  1.46  5.0   6.0  50.97

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
len(data_2021)
# Out:
# 8760

# %%
faltantes(data_2021)
# Out:
# Faltantes totales en el DataFrame: 3188
# (CO       750
#  O3       612
#  NO2      543
#  PM2.5    442
#  SO2      430
#  PM10     411
#  date       0
#  dtype: int64,
#  3188)

# %%
import sys
sys.path.append('..')
from plot_series import *

# %%
plotserie(data_2021, 'SO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2021'}>,
#          <Axes: title={'center': 'Feb 2021'}>,
#          <Axes: title={'center': 'Mar 2021'}>,
#          <Axes: title={'center': 'Apr 2021'}>],
#         [<Axes: title={'center': 'May 2021'}>,
#          <Axes: title={'center': 'Jun 2021'}>,
#          <Axes: title={'center': 'Jul 2021'}>,
#          <Axes: title={'center': 'Aug 2021'}>],
#         [<Axes: title={'center': 'Sep 2021'}>,
#          <Axes: title={'center': 'Oct 2021'}>,
#          <Axes: title={'center': 'Nov 2021'}>,
#          <Axes: title={'center': 'Dec 2021'}>]], dtype=object))

# %%
plotserie(data_2021, 'NO2')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2021'}>,
#          <Axes: title={'center': 'Feb 2021'}>,
#          <Axes: title={'center': 'Mar 2021'}>,
#          <Axes: title={'center': 'Apr 2021'}>],
#         [<Axes: title={'center': 'May 2021'}>,
#          <Axes: title={'center': 'Jun 2021'}>,
#          <Axes: title={'center': 'Jul 2021'}>,
#          <Axes: title={'center': 'Aug 2021'}>],
#         [<Axes: title={'center': 'Sep 2021'}>,
#          <Axes: title={'center': 'Oct 2021'}>,
#          <Axes: title={'center': 'Nov 2021'}>,
#          <Axes: title={'center': 'Dec 2021'}>]], dtype=object))

# %%
plotserie(data_2021, 'O3')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2021'}>,
#          <Axes: title={'center': 'Feb 2021'}>,
#          <Axes: title={'center': 'Mar 2021'}>,
#          <Axes: title={'center': 'Apr 2021'}>],
#         [<Axes: title={'center': 'May 2021'}>,
#          <Axes: title={'center': 'Jun 2021'}>,
#          <Axes: title={'center': 'Jul 2021'}>,
#          <Axes: title={'center': 'Aug 2021'}>],
#         [<Axes: title={'center': 'Sep 2021'}>,
#          <Axes: title={'center': 'Oct 2021'}>,
#          <Axes: title={'center': 'Nov 2021'}>,
#          <Axes: title={'center': 'Dec 2021'}>]], dtype=object))

# %%
plotserie(data_2021, 'CO')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2021'}>,
#          <Axes: title={'center': 'Feb 2021'}>,
#          <Axes: title={'center': 'Mar 2021'}>,
#          <Axes: title={'center': 'Apr 2021'}>],
#         [<Axes: title={'center': 'May 2021'}>,
#          <Axes: title={'center': 'Jun 2021'}>,
#          <Axes: title={'center': 'Jul 2021'}>,
#          <Axes: title={'center': 'Aug 2021'}>],
#         [<Axes: title={'center': 'Sep 2021'}>,
#          <Axes: title={'center': 'Oct 2021'}>,
#          <Axes: title={'center': 'Nov 2021'}>,
#          <Axes: title={'center': 'Dec 2021'}>]], dtype=object))

# %%
plotserie(data_2021, 'PM2.5')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2021'}>,
#          <Axes: title={'center': 'Feb 2021'}>,
#          <Axes: title={'center': 'Mar 2021'}>,
#          <Axes: title={'center': 'Apr 2021'}>],
#         [<Axes: title={'center': 'May 2021'}>,
#          <Axes: title={'center': 'Jun 2021'}>,
#          <Axes: title={'center': 'Jul 2021'}>,
#          <Axes: title={'center': 'Aug 2021'}>],
#         [<Axes: title={'center': 'Sep 2021'}>,
#          <Axes: title={'center': 'Oct 2021'}>,
#          <Axes: title={'center': 'Nov 2021'}>,
#          <Axes: title={'center': 'Dec 2021'}>]], dtype=object))

# %%
plotserie(data_2021, 'PM10')
# Out:
# (<Figure size 1600x900 with 12 Axes>,
#  array([[<Axes: title={'center': 'Jan 2021'}>,
#          <Axes: title={'center': 'Feb 2021'}>,
#          <Axes: title={'center': 'Mar 2021'}>,
#          <Axes: title={'center': 'Apr 2021'}>],
#         [<Axes: title={'center': 'May 2021'}>,
#          <Axes: title={'center': 'Jun 2021'}>,
#          <Axes: title={'center': 'Jul 2021'}>,
#          <Axes: title={'center': 'Aug 2021'}>],
#         [<Axes: title={'center': 'Sep 2021'}>,
#          <Axes: title={'center': 'Oct 2021'}>,
#          <Axes: title={'center': 'Nov 2021'}>,
#          <Axes: title={'center': 'Dec 2021'}>]], dtype=object))
