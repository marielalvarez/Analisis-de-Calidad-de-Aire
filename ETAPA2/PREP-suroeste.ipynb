# %%
import pandas as pd

df = pd.read_excel('../data_para_limpiar/suroeste.xlsx')

# %%
import PREPHelper
import importlib
importlib.reload(PREPHelper)
# Out:
# <module 'PREPHelper' from '/Users/marielalvarez/2025/5to_sem/multivariados/Application-of-multivariate-methods-in-data-science/notebooks_etapa2/PREPHelper.py'>

# %%
from PREPHelper import *

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

df = df.reindex(full_index)

print(df.isna().sum())
# Out:
# CO        1314
# NO         776
# NO2        753
# NOX        753
# O3        1254
# PM10       646
# PM2.5     2737
# PRS        919
# RAINF      531
# RH         541
# SO2        813
# SR         408
# TOUT       527
# WDR      14110
# WDV       9054
# WSR        619
# dtype: int64
# /var/folders/l9/hx3k3fcs03d6gz71m2n3t1c80000gn/T/ipykernel_10166/3299174593.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

# %%
cols = ['PM10', 'NO2', 'CO', 'SO2', 'O3', 'PM2.5']
data = impute_with_random_forest(df, cols)

# %%
data_overview(data)
# Out:
# Dataset shape: (22632, 16)
#
# Data Types and Null Values:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 22632 entries, 2022-01-01 00:00:00 to 2024-07-31 23:00:00
# Freq: h
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO      22632 non-null  float64
#  1   NO      21856 non-null  float64
#  2   NO2     22632 non-null  float64
#  3   NOX     21879 non-null  float64
#  4   O3      22632 non-null  float64
#  5   PM10    22632 non-null  float64
#  6   PM2.5   22632 non-null  float64
#  7   PRS     21713 non-null  float64
#  8   RAINF   22101 non-null  float64
#  9   RH      22091 non-null  float64
#  10  SO2     22632 non-null  float64
#  11  SR      22224 non-null  float64
#  12  TOUT    22105 non-null  float64
#  13  WDR     8522 non-null   float64
#  14  WDV     13578 non-null  float64
#  15  WSR     22013 non-null  float64
# dtypes: float64(16)
# memory usage: 3.4 MB
# None
#
# Data Summary (Descriptive Statistics):
#                  CO            NO           NO2           NOX            O3  \
# count  22632.000000  21856.000000  22632.000000  21879.000000  22632.000000
# mean       1.711897     15.010803     18.176436     33.183651     27.589377
# std        0.845837     27.896877     11.144353     35.785223     20.713827
# min        0.050000      0.800000      0.200000      0.600000      1.000000
# 25%        0.900000      3.400000     10.100000     13.500000     11.000000
# 50%        1.810000      5.300000     15.100000     21.300000     23.000000
# 75%        2.410000     12.300000     23.600000     37.000000     38.000000
# max        6.520000    362.700000     92.500000    412.700000    164.000000
#
#                PM10         PM2.5           PRS         RAINF            RH  \
# count  22632.000000  22632.000000  21713.000000  22101.000000  22091.000000
# mean      65.723709     25.454380    700.927113      0.005012     53.884795
# std       48.006560     17.964183      4.392322      0.219232     20.734258
# min        3.000000      2.000000    680.000000      0.000000      1.000000
# 25%       37.000000     13.686450    698.600000      0.000000     38.000000
# 50%       52.000000     21.000000    701.000000      0.000000     55.000000
# 75%       79.000000     32.170000    703.400000      0.000000     70.500000
# max      802.000000    556.000000    715.500000     17.990000    100.000000
#
#                 SO2            SR          TOUT          WDR           WDV  \
# count  22632.000000  22224.000000  22105.000000  8522.000000  13578.000000
# mean       6.160967      0.181288     22.781845   140.808144    145.184269
# std        3.167349      0.390797      7.370729    75.991903     80.556176
# min        0.500000     -0.004000     -2.600000     1.000000      1.000000
# 25%        4.600000      0.000000     17.720000    97.000000     97.000000
# 50%        5.500000      0.000000     23.710000   114.000000    114.000000
# 75%        7.000000      0.298000     28.030000   146.000000    150.000000
# max      177.800000      7.786000     43.420000   360.000000    360.000000
#
#                 WSR
# count  22013.000000
# mean       8.518598
# std        4.704079
# min        0.100000
# 25%        4.500000
# 50%        8.000000
# 75%       12.100000
# max       30.400000
#
# Missing Values:
# CO           0
# NO         776
# NO2          0
# NOX        753
# O3           0
# PM10         0
# PM2.5        0
# PRS        919
# RAINF      531
# RH         541
# SO2          0
# SR         408
# TOUT       527
# WDR      14110
# WDV       9054
# WSR        619
# dtype: int64
#
# First 5 rows:
#                           CO    NO     NO2   NOX     O3    PM10       PM2.5  \
# 2022-01-01 00:00:00  2.55205   NaN  13.347   NaN  41.09   49.63   38.368226
# 2022-01-01 01:00:00  3.28000  29.1  46.500  75.6   5.00  232.00  225.000000
# 2022-01-01 02:00:00  3.25000  38.7  42.000  80.7   5.00  234.00  181.000000
# 2022-01-01 03:00:00  3.02000  39.1  40.400  79.5   4.00  183.00  140.000000
# 2022-01-01 04:00:00  2.73000  37.2  39.000  76.2   3.00  137.00   91.000000
#
#                        PRS  RAINF    RH    SO2   SR   TOUT    WDR  WDV  WSR
# 2022-01-01 00:00:00    NaN    NaN   NaN  7.171  NaN    NaN    NaN  NaN  NaN
# 2022-01-01 01:00:00  694.9    0.0  57.0  5.400  0.0  19.11  287.0  NaN  3.4
# 2022-01-01 02:00:00  694.9    0.0  57.0  5.300  0.0  18.50  333.0  NaN  1.4
# 2022-01-01 03:00:00  694.6    0.0  58.0  5.400  0.0  18.19  273.0  NaN  3.3
# 2022-01-01 04:00:00  694.4    0.0  55.0  5.900  0.0  18.78  315.0  NaN  1.6

# %% [markdown]
# ## se usarán las variables PM10, NO2, CO, SO2, O3 y PM2.5

# %%
describe_variables(data)
# Out:
# Description of variables:
#
# Column: PM10
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: NO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: CO
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: SO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: O3
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: PM2.5
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------

# %%
explore_quantitative_variables(data)
# Out:
# Measures of Central Tendency:
# PM10 - Mean: 65.72, Median: 52.00, Mode: 31.00
# NO2 - Mean: 18.18, Median: 15.10, Mode: 13.35
# CO - Mean: 1.71, Median: 1.81, Mode: 2.49
# SO2 - Mean: 6.16, Median: 5.50, Mode: 5.30
# O3 - Mean: 27.59, Median: 23.00, Mode: 8.00
# PM2.5 - Mean: 25.45, Median: 21.00, Mode: 20.67
#
# Measures of Dispersion:
# PM10 - Range: 799.00, Variance: 2304.63, Std Dev: 48.01
# NO2 - Range: 92.30, Variance: 124.20, Std Dev: 11.14
# CO - Range: 6.47, Variance: 0.72, Std Dev: 0.85
# SO2 - Range: 177.30, Variance: 10.03, Std Dev: 3.17
# O3 - Range: 163.00, Variance: 429.06, Std Dev: 20.71
# PM2.5 - Range: 554.00, Variance: 322.71, Std Dev: 17.96

# %%
visualize_outliers(data)
# Out:
# PM10 - Outliers: 1357 outliers
# NO2 - Outliers: 742 outliers
# CO - Outliers: 39 outliers
# SO2 - Outliers: 1489 outliers
# O3 - Outliers: 596 outliers
# PM2.5 - Outliers: 923 outliers

# %%
plot_histograms(data)

# %%
plot_correlation_heatmap(data)

# %%
data.to_excel('../data_preparada/suroeste_prep.xlsx')
