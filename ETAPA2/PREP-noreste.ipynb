# %%
import pandas as pd

df = pd.read_excel('../data_para_limpiar/noreste2.xlsx')

# %%
from PREPHelper import *

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

df = df.reindex(full_index)

print(df.isna().sum())
# Out:
# CO        2147
# NO         603
# NO2        616
# NOX        576
# O3        1453
# PM10       813
# PM2.5     2386
# PRS        623
# RAINF      497
# RH        1150
# SO2       1045
# SR         198
# TOUT       523
# WDR      16383
# WDV       9197
# WSR        595
# dtype: int64
# /var/folders/l9/hx3k3fcs03d6gz71m2n3t1c80000gn/T/ipykernel_24373/3299174593.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

# %%
cols = ['PM10', 'NO2', 'CO', 'SO2', 'O3', 'PM2.5']
data = impute_with_random_forest(df, cols)

# %%
data_overview(data)
# Out:
# Dataset shape: (22632, 16)
#
# Data Types and Null Values:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 22632 entries, 2022-01-01 00:00:00 to 2024-07-31 23:00:00
# Freq: h
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO      22632 non-null  float64
#  1   NO      22029 non-null  float64
#  2   NO2     22632 non-null  float64
#  3   NOX     22056 non-null  float64
#  4   O3      22632 non-null  float64
#  5   PM10    22632 non-null  float64
#  6   PM2.5   22632 non-null  float64
#  7   PRS     22009 non-null  float64
#  8   RAINF   22135 non-null  float64
#  9   RH      21482 non-null  float64
#  10  SO2     22632 non-null  float64
#  11  SR      22434 non-null  float64
#  12  TOUT    22109 non-null  float64
#  13  WDR     6249 non-null   float64
#  14  WDV     13435 non-null  float64
#  15  WSR     22037 non-null  float64
# dtypes: float64(16)
# memory usage: 3.4 MB
# None
#
# Data Summary (Descriptive Statistics):
#                  CO            NO           NO2           NOX            O3  \
# count  22632.000000  22029.000000  22632.000000  22056.000000  22632.000000
# mean       2.001772     15.031763     17.439421     32.814903     22.530071
# std        0.893269     18.856440     10.872943     26.744093     14.580008
# min        0.000000      0.300000      0.000000      0.500000      2.000000
# 25%        1.480000      5.200000      9.600000     16.700000     11.035000
# 50%        1.820000      9.400000     15.200000     25.700000     19.000000
# 75%        2.290000     17.100000     23.000000     39.600000     30.000000
# max       13.380000    284.800000    100.800000    351.200000    131.000000
#
#                PM10         PM2.5           PRS    RAINF            RH  \
# count  22632.000000  22632.000000  22009.000000  22135.0  21482.000000
# mean      73.206702     21.788122    714.466400      0.0     55.479285
# std       44.396182     15.617384      5.379125      0.0     21.352475
# min        3.000000      2.000000    655.400000      0.0      1.000000
# 25%       46.790000     11.000000    711.200000      0.0     38.000000
# 50%       64.000000     19.000000    714.100000      0.0     57.000000
# 75%       88.000000     29.000000    717.500000      0.0     73.000000
# max      799.000000    351.000000    733.800000      0.0    190.000000
#
#                 SO2            SR          TOUT          WDR           WDV  \
# count  22632.000000  22434.000000  22109.000000  6249.000000  13435.000000
# mean       4.508357      0.150478     23.915491   169.204193    211.411314
# std        3.650629      0.218135      7.779869   100.347136     91.992450
# min        0.700000      0.000000     -2.510000     1.000000      1.000000
# 25%        2.600000      0.000000     18.650000   108.000000    138.000000
# 50%        3.400000      0.008000     24.740000   135.000000    207.000000
# 75%        4.900000      0.274000     29.280000   275.000000    301.000000
# max       76.800000      2.663000    112.390000   360.000000    360.000000
#
#                 WSR
# count  22037.000000
# mean       8.895027
# std        5.612306
# min        0.100000
# 25%        5.100000
# 50%        8.100000
# 75%       11.600000
# max      112.700000
#
# Missing Values:
# CO           0
# NO         603
# NO2          0
# NOX        576
# O3           0
# PM10         0
# PM2.5        0
# PRS        623
# RAINF      497
# RH        1150
# SO2          0
# SR         198
# TOUT       523
# WDR      16383
# WDV       9197
# WSR        595
# dtype: int64
#
# First 5 rows:
#                        CO    NO   NO2   NOX   O3   PM10  PM2.5    PRS  RAINF  \
# 2022-01-01 00:00:00  3.04  16.8  30.0  46.8  9.0  182.0  137.0  706.3    0.0
# 2022-01-01 01:00:00  2.60   8.8  26.4  35.2  9.0  166.0  113.0  705.9    0.0
# 2022-01-01 02:00:00  2.86  10.8  27.3  38.2  6.0  184.0  141.0  705.7    0.0
# 2022-01-01 03:00:00  2.98  16.4  28.4  44.8  5.0  201.0  168.0  705.5    0.0
# 2022-01-01 04:00:00  2.37   9.3  26.5  35.8  5.0  216.0  139.0  705.4    0.0
#
#                        RH  SO2   SR   TOUT    WDR  WDV  WSR
# 2022-01-01 00:00:00  63.0  3.7  0.0  22.79   72.0  NaN  1.4
# 2022-01-01 01:00:00  66.0  3.3  0.0  21.70  357.0  NaN  3.2
# 2022-01-01 02:00:00  71.0  3.3  0.0  20.41  287.0  NaN  4.0
# 2022-01-01 03:00:00  72.0  3.4  0.0  19.81  291.0  NaN  4.7
# 2022-01-01 04:00:00  73.0  3.1  0.0  19.22  288.0  NaN  5.9

# %% [markdown]
# ## se usarán las variables PM10, NO2, CO, SO2, O3 y PM2.5

# %%
describe_variables(data)
# Out:
# Description of variables:
#
# Column: PM10
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: NO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: CO
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: SO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: O3
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: PM2.5
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------

# %%
explore_quantitative_variables(data)
# Out:
# Measures of Central Tendency:
# PM10 - Mean: 73.21, Median: 64.00, Mode: 50.00
# NO2 - Mean: 17.44, Median: 15.20, Mode: 3.60
# CO - Mean: 2.00, Median: 1.82, Mode: 1.81
# SO2 - Mean: 4.51, Median: 3.40, Mode: 2.50
# O3 - Mean: 22.53, Median: 19.00, Mode: 11.00
# PM2.5 - Mean: 21.79, Median: 19.00, Mode: 13.00
#
# Measures of Dispersion:
# PM10 - Range: 796.00, Variance: 1971.02, Std Dev: 44.40
# NO2 - Range: 100.80, Variance: 118.22, Std Dev: 10.87
# CO - Range: 13.38, Variance: 0.80, Std Dev: 0.89
# SO2 - Range: 76.10, Variance: 13.33, Std Dev: 3.65
# O3 - Range: 129.00, Variance: 212.58, Std Dev: 14.58
# PM2.5 - Range: 349.00, Variance: 243.90, Std Dev: 15.62

# %%
visualize_outliers(data)
# Out:
# PM10 - Outliers: 1143 outliers
# NO2 - Outliers: 596 outliers
# CO - Outliers: 1215 outliers
# SO2 - Outliers: 2038 outliers
# O3 - Outliers: 546 outliers
# PM2.5 - Outliers: 629 outliers

# %%
plot_histograms(data)

# %%
plot_correlation_heatmap(data)

# %%
data.to_excel('../data_preparada/noreste_prep.xlsx')
